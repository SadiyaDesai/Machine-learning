# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel("smalldata.xlsx")

# %%
df
# Out:
#            Date        Time State     Group  Unit  Sales
# 0    2020-10-01     Morning    WA      Kids     8  20000
# 1    2020-10-01     Morning    WA       Men     8  20000
# 2    2020-10-01     Morning    WA     Women     4  10000
# 3    2020-10-01     Morning    WA   Seniors    15  37500
# 4    2020-10-01   Afternoon    WA      Kids     3   7500
# ...         ...         ...   ...       ...   ...    ...
# 7555 2020-12-30   Afternoon   TAS   Seniors    14  35000
# 7556 2020-12-30     Evening   TAS      Kids    15  37500
# 7557 2020-12-30     Evening   TAS       Men    15  37500
# 7558 2020-12-30     Evening   TAS     Women    11  27500
# 7559 2020-12-30     Evening   TAS   Seniors    13  32500
#
# [7560 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'State', 'Group', 'Unit', 'Sales'], dtype='object')

# %%
df.dtypes
# Out:
# Date     datetime64[ns]
# Time             object
# State            object
# Group            object
# Unit              int64
# Sales             int64
# dtype: object

# %%
df.Time.value_counts()
# Out:
#  Morning      2520
#  Afternoon    2520
#  Evening      2520
# Name: Time, dtype: int64

# %%
df.Time
# Out:
# 0          Morning
# 1          Morning
# 2          Morning
# 3          Morning
# 4        Afternoon
# 5        Afternoon
# 6        Afternoon
# 7        Afternoon
# 8          Evening
# 9          Evening
# 10         Evening
# 11         Evening
# 12         Morning
# 13         Morning
# 14         Morning
# 15         Morning
# 16       Afternoon
# 17       Afternoon
# 18       Afternoon
# 19       Afternoon
# 20         Evening
# 21         Evening
# 22         Evening
# 23         Evening
# 24         Morning
# 25         Morning
# 26         Morning
# 27         Morning
# 28       Afternoon
# 29       Afternoon
# 30       Afternoon
# 31       Afternoon
# 32         Evening
# 33         Evening
# 34         Evening
# 35         Evening
# 36         Morning
# 37         Morning
# 38         Morning
# 39         Morning
# 40       Afternoon
# 41       Afternoon
# 42       Afternoon
# 43       Afternoon
# 44         Evening
# 45         Evening
# 46         Evening
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7560 non-null   datetime64[ns]
#  1   Time    7560 non-null   object
#  2   State   7560 non-null   object
#  3   Group   7560 non-null   object
#  4   Unit    7560 non-null   int64
#  5   Sales   7560 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 354.5+ KB

# %%
df.columns.unique()
# Out:
# Index(['Date', 'Time', 'State', 'Group', 'Unit', 'Sales'], dtype='object')

# %%
df.Time.unique()
# Out:
# array([' Morning', ' Afternoon', ' Evening'], dtype=object)

# %%
df.Time=df.Time.str.strip()

# %%
df.Time.unique()
# Out:
# array(['Morning', 'Afternoon', 'Evening'], dtype=object)

# %%
data_by_time=df.groupby("Time").get_group("Afternoon")
data_by_time.plot(kind="line",subplots="True")
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
sh=df.shape
sh
# Out:
# (7560, 6)

# %%
rows=sh[0]
rows
# Out:
# 7560

# %%
column1=sh[1]

# %%
column1
# Out:
# 6

# %%
#missing entry

# %%
df.isna().sum()
# Out:
# Date     0
# Time     0
# State    0
# Group    0
# Unit     0
# Sales    0
# dtype: int64

# %%
#to display all data of rows
pd.options.display.max_rows

# %%
pd.set_option('display.max_row',None)

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
df
# Out:
#            Date       Time State     Group  Unit   Sales
# 0    2020-10-01    Morning    WA      Kids     8   20000
# 1    2020-10-01    Morning    WA       Men     8   20000
# 2    2020-10-01    Morning    WA     Women     4   10000
# 3    2020-10-01    Morning    WA   Seniors    15   37500
# 4    2020-10-01  Afternoon    WA      Kids     3    7500
# 5    2020-10-01  Afternoon    WA       Men    10   25000
# 6    2020-10-01  Afternoon    WA     Women     3    7500
# 7    2020-10-01  Afternoon    WA   Seniors    11   27500
# 8    2020-10-01    Evening    WA      Kids    15   37500
# 9    2020-10-01    Evening    WA       Men    15   37500
# 10   2020-10-01    Evening    WA     Women     3    7500
# 11   2020-10-01    Evening    WA   Seniors    10   25000
# 12   2020-10-01    Morning    NT      Kids    13   32500
# 13   2020-10-01    Morning    NT       Men     5   12500
# 14   2020-10-01    Morning    NT     Women     4   10000
# ...

# %%
#we r takinfdg state category

# %%
g1=df.groupby("State")["Sales"].sum()

# %%
g1
# Out:
# State
#  NSW     74970000
#  NT      22580000
#  QLD     33417500
#  SA      58857500
#  TAS     22760000
#  VIC    105565000
#  WA      22152500
# Name: Sales, dtype: int64

# %%
g1.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df.head(3)
# Out:
#         Date     Time State   Group  Unit  Sales
# 0 2020-10-01  Morning    WA    Kids     8  20000
# 1 2020-10-01  Morning    WA     Men     8  20000
# 2 2020-10-01  Morning    WA   Women     4  10000

# %%
df.groupby("Group")['Sales'].sum()#by group
# Out:
# Group
#  Kids       85072500
#  Men        85750000
#  Seniors    84037500
#  Women      85442500
# Name: Sales, dtype: int64

# %%
g2=df.groupby("Group")['Sales'].sum()
g2.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Group'>

# %%
df.head(3)
# Out:
#         Date      Time State   Group  Unit  Sales
# 0 2020-10-01   Morning    WA    Kids     8  20000
# 1 2020-10-01   Morning    WA     Men     8  20000
# 2 2020-10-01   Morning    WA   Women     4  10000

# %%
df.sort_values("Sales")
# Out:
#            Date        Time State     Group  Unit   Sales
# 4622 2020-11-26     Morning    WA     Women     2    5000
# 4451 2020-11-23     Evening   TAS   Seniors     2    5000
# 3867 2020-11-17     Morning    WA   Seniors     2    5000
# 2851 2020-11-04   Afternoon   TAS   Seniors     2    5000
# 3454 2020-11-12     Evening    WA     Women     2    5000
# ...         ...         ...   ...       ...   ...     ...
# 6174 2020-12-14   Afternoon   VIC     Women    65  162500
# 5842 2020-12-10     Evening   VIC     Women    65  162500
# 5423 2020-12-05     Evening   VIC   Seniors    65  162500
# 5759 2020-12-09     Evening   VIC   Seniors    65  162500
# 7019 2020-12-24     Evening   VIC   Seniors    65  162500
#
# [7560 rows x 6 columns]

# %%
low_reven=df.groupby("State")["Sales"].sum()
low_reven
# Out:
# State
#  NSW     74970000
#  NT      22580000
#  QLD     33417500
#  SA      58857500
#  TAS     22760000
#  VIC    105565000
#  WA      22152500
# Name: Sales, dtype: int64

# %%
low_reven.sort_index().tail(1)
# Out:
# State
#  WA    22152500
# Name: Sales, dtype: int64

# %%
low_reven.plot()
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df.Time.unique()
# Out:
# array([' Morning', ' Afternoon', ' Evening'], dtype=object)

# %%
df.Time=df.Time.str.strip(i)

# %%
df
# Out:
#            Date       Time State     Group  Unit  Sales
# 0    2020-10-01    Morning    WA      Kids     8  20000
# 1    2020-10-01    Morning    WA       Men     8  20000
# 2    2020-10-01    Morning    WA     Women     4  10000
# 3    2020-10-01    Morning    WA   Seniors    15  37500
# 4    2020-10-01  Afternoon    WA      Kids     3   7500
# ...         ...        ...   ...       ...   ...    ...
# 7555 2020-12-30  Afternoon   TAS   Seniors    14  35000
# 7556 2020-12-30    Evening   TAS      Kids    15  37500
# 7557 2020-12-30    Evening   TAS       Men    15  37500
# 7558 2020-12-30    Evening   TAS     Women    11  27500
# 7559 2020-12-30    Evening   TAS   Seniors    13  32500
#
# [7560 rows x 6 columns]

# %%
df.columns.unique()
# Out:
# Index(['Date', 'Time', 'State', 'Group', 'Unit', 'Sales'], dtype='object')

# %%
df.Time.unique()
# Out:
# array(['Morning', 'Afternoon', 'Evening'], dtype=object)

# %%
df.groupby("Time")["Sales"].sum()
# Out:
# Time
# Afternoon    114007500
# Evening      112087500
# Morning      114207500
# Name: Sales, dtype: int64

# %%
g2=df.groupby("Time")["Sales"].sum()

# %%
g2.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df.head()
# Out:
#         Date       Time State     Group  Unit  Sales
# 0 2020-10-01    Morning    WA      Kids     8  20000
# 1 2020-10-01    Morning    WA       Men     8  20000
# 2 2020-10-01    Morning    WA     Women     4  10000
# 3 2020-10-01    Morning    WA   Seniors    15  37500
# 4 2020-10-01  Afternoon    WA      Kids     3   7500

# %%
df.groupby("Group")["Sales"].sum()
# Out:
# Group
#  Kids       85072500
#  Men        85750000
#  Seniors    84037500
#  Women      85442500
# Name: Sales, dtype: int64

# %%
rev_by_group=df.groupby("Group")["Sales"].sum()

# %%
rev_by_group.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Group'>

# %%
df.head(2)
# Out:
#         Date     Time State  Group  Unit  Sales
# 0 2020-10-01  Morning    WA   Kids     8  20000
# 1 2020-10-01  Morning    WA    Men     8  20000

# %%
s=pd.Series(["20-12-1223","Afternoon","uk","men",1,"34433"],index=df.columns)

# %%
df.append(s,ignore_index=True)
# Out:
# C:\Users\sadiy\AppData\Local\Temp\ipykernel_4128\1925300445.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(s,ignore_index=True)
#                      Date       Time State     Group  Unit  Sales
# 0     2020-10-01 00:00:00    Morning    WA      Kids     8  20000
# 1     2020-10-01 00:00:00    Morning    WA       Men     8  20000
# 2     2020-10-01 00:00:00    Morning    WA     Women     4  10000
# 3     2020-10-01 00:00:00    Morning    WA   Seniors    15  37500
# 4     2020-10-01 00:00:00  Afternoon    WA      Kids     3   7500
# ...                   ...        ...   ...       ...   ...    ...
# 7556  2020-12-30 00:00:00    Evening   TAS      Kids    15  37500
# 7557  2020-12-30 00:00:00    Evening   TAS       Men    15  37500
# 7558  2020-12-30 00:00:00    Evening   TAS     Women    11  27500
# 7559  2020-12-30 00:00:00    Evening   TAS   Seniors    13  32500
# ...

# %%
df.tail(1)
# Out:
#            Date     Time State     Group  Unit  Sales
# 7559 2020-12-30  Evening   TAS   Seniors    13  32500

# %%
df1=pd.DataFrame([[1,2,3],["A","B","C"]])

# %%
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  A  B  C

# %%
df1.append([[11,12,13]],ignore_index="True")
# Out:
# C:\Users\sadiy\AppData\Local\Temp\ipykernel_4128\3638620406.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append([[11,12,13]],ignore_index="True")
#     0   1   2
# 0   1   2   3
# 1   A   B   C
# 2  11  12  13

# %%
df.head(2)
# Out:
#         Date     Time State  Group  Unit  Sales
# 0 2020-10-01  Morning    WA   Kids     8  20000
# 1 2020-10-01  Morning    WA    Men     8  20000

# %%
df.append([["as","sa","re",12,"re","rt"]],ignore_index=True)
# Out:
# C:\Users\sadiy\AppData\Local\Temp\ipykernel_4128\2456083397.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append([["as","sa","re",12,"re","rt"]],ignore_index=True)
#            Date       Time State     Group  Unit    Sales    0    1    2  \
# 0    2020-10-01    Morning    WA      Kids   8.0  20000.0  NaN  NaN  NaN
# 1    2020-10-01    Morning    WA       Men   8.0  20000.0  NaN  NaN  NaN
# 2    2020-10-01    Morning    WA     Women   4.0  10000.0  NaN  NaN  NaN
# 3    2020-10-01    Morning    WA   Seniors  15.0  37500.0  NaN  NaN  NaN
# 4    2020-10-01  Afternoon    WA      Kids   3.0   7500.0  NaN  NaN  NaN
# ...         ...        ...   ...       ...   ...      ...  ...  ...  ...
# 7556 2020-12-30    Evening   TAS      Kids  15.0  37500.0  NaN  NaN  NaN
# 7557 2020-12-30    Evening   TAS       Men  15.0  37500.0  NaN  NaN  NaN
# ...

# %%
df
# Out:
#            Date       Time State     Group  Unit  Sales
# 0    2020-10-01    Morning    WA      Kids     8  20000
# 1    2020-10-01    Morning    WA       Men     8  20000
# 2    2020-10-01    Morning    WA     Women     4  10000
# 3    2020-10-01    Morning    WA   Seniors    15  37500
# 4    2020-10-01  Afternoon    WA      Kids     3   7500
# ...         ...        ...   ...       ...   ...    ...
# 7555 2020-12-30  Afternoon   TAS   Seniors    14  35000
# 7556 2020-12-30    Evening   TAS      Kids    15  37500
# 7557 2020-12-30    Evening   TAS       Men    15  37500
# 7558 2020-12-30    Evening   TAS     Women    11  27500
# 7559 2020-12-30    Evening   TAS   Seniors    13  32500
#
# [7560 rows x 6 columns]
